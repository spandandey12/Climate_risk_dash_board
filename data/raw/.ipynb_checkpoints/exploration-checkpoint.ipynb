# %%
import pandas as pd

# %%
df = pd.read_csv('data/climate-risk-index-1.csv')

# %% [markdown]
# ## Accquiring information

# %%
print("Looking at the data:")
print(df.head())
print()
print("----------------------"*5)
print("Columns:")
print(df.columns)
print()
print("----------------------"*5)
print("Information:")
print(df.info())
print()
print("----------------------"*5)
print("Statistics")
print(df.describe())
print()
print("----------------------"*5)
print("Sum of Na")
print(df.isna().sum())
# Out:
# Looking at the data:
#    index  cartodb_id  the_geom  the_geom_webmercator       country  cri_rank  \
# 0      0           1       NaN                   NaN  Saudi Arabia        79
# 1      1           2       NaN                   NaN       Romania        61
# 2      2           3       NaN                   NaN         Spain        69
# 3      3           4       NaN                   NaN      Slovenia       135
# 4      4           5       NaN                   NaN   South Sudan       133
#
#    cri_score  fatalities_per_100k_rank  fatalities_per_100k_total  \
# 0      72.50                        18                       0.45
# 1      61.50                       112                       0.01
# 2      66.33                        74                       0.05
# 3     124.50                       114                       0.00
# 4     117.33                       114                       0.00
#
#    fatalities_rank  fatalities_total  losses_per_gdp__rank  \
# ...

# %%
important_cols=[
    "country",
    "cri_score",
    "fatalities_total",
    "fatalities_per_100k_total",
    "losses_usdm_ppp_total"
]
df=df[important_cols]
df.head()
# Out:
#         country  cri_score  fatalities_total  fatalities_per_100k_total  \
# 0  Saudi Arabia      72.50               140                       0.45
# 1       Romania      61.50                 1                       0.01
# 2         Spain      66.33                22                       0.05
# 3      Slovenia     124.50                 0                       0.00
# 4   South Sudan     117.33                 0                       0.00
#
#    losses_usdm_ppp_total
# 0                  1.229
# 1               2797.884
# 2                637.070
# 3                  0.000
# 4                  0.508
